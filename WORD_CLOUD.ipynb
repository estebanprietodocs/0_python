# %% [markdown]
# ## WORD CLOUD
# ##### RESOURCE = https://www.datacamp.com/community/tutorials/wordcloud-python
# ##### ES POSIBLE ARMAR LA NUBE DENTRO DE OTRAS IMAGES, O JUNTO A UNA BANDERA, ETC

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Mumes\Documents\ds_salary_proj\salary_data_cleaned.csv')
df.head(2)
# Out:
#                   Job Title              Salary Estimate  \
# 0  Marketing Data Scientist  $87K-$139K (Glassdoor est.)
# 1            Data Scientist  $87K-$139K (Glassdoor est.)
#
#                                      Job Description  Rating    Company Name  \
# 0  Who we are:\n\nSoFi is a digital personal fina...     3.2       SoFi\n3.2
# 1  The opportunity\n\n\nGrammarly empowers people...     5.0  Grammarly\n5.0
#
#             Location       Headquarters                    Size  Founded  \
# 0  San Francisco, CA  San Francisco, CA  1001 to 5000 employees     2011
# 1  San Francisco, CA  San Francisco, CA    201 to 500 employees     2009
#
#    Type of ownership  ... max_salary avg_salary  company_txt  job_state  age  \
# 0  Company - Private  ...        139      113.0       SoFi\n         CA    9
# 1  Company - Private  ...        139      113.0  Grammarly\n         CA   11
#
#    python_yn  r_studio_yn spark_yn excel_yn  aws_yn
# ...

# %%
# Start with one review:
text = df['Job Description'][0] ### texto de la posicion 0

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file(r'C:\Users\Mumes\0_python\texto_posicion_0.png')

# %%
# Start with one review:
text = df['Job Description'][1] ### texto de la posicion 0

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
